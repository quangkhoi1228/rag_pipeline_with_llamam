# %%
from pymilvus import (
    connections,
    Collection,
    FieldSchema,
    CollectionSchema,
    DataType,
    utility,
)
import pandas as pd
from scipy import sparse
import numpy as np
import gc
import json

connections.connect(uri="http://localhost:19530")  # Replace with your Milvus server IP

# %%
from pymilvus import AnnSearchRequest
from pymilvus import WeightedRanker, RRFRanker

# %%
collection = Collection(name="bat_dong_san")
collection.load()

# %%
def query(query_embeds, rerank, limit=3):
    content_sparse_search_params = {
        "data": query_embeds["sparse"],
        "anns_field": "content_sparse",
        "param": {
            "metric_type": "IP",
        },
        "limit": limit,
    }
    content_sparse_request = AnnSearchRequest(**content_sparse_search_params)

    content_dense_search_params = {
        "data": query_embeds["dense"],
        "anns_field": "content_dense",
        "param": {
            "metric_type": "IP",
            "ef": 20,
        },
        "limit": limit,
    }
    content_dense_request = AnnSearchRequest(**content_dense_search_params)

    reqs = [
        content_sparse_request,
        content_dense_request,
    ]

    res = collection.hybrid_search(
        reqs,  # List of AnnSearchRequests created in step 1
        rerank,  # Reranking strategy specified in step 2
        limit=limit,  # Number of final search results to return
        output_fields=["id", "url", "title_text", "content_text"],
    )
    return res

# %%
def get_retrieval(df, embed_col, rerank, limit=10):
    full_context = []

    for i, row in df.iterrows():
        res = query(row[embed_col], rerank=rerank, limit=limit)

        context = []
        for item in res[0]:
            item_dict = {
                "id": item.id,
                "score": item.score,
                "title": item.entity.get("title_text"),
                "content": item.entity.get("content_text"),
            }
            context.append(item_dict)
        full_context.append(context)
    return full_context

# %%
def hit_rate(expected_ids, actual_ids, k):
    """
    Hit Rate (HR) measures whether the expected item is in the actual top-k list.
    """
    return int(any([item in actual_ids for item in expected_ids]))


def mrr(expected_ids, actual_ids, k):
    """
    Mean Reciprocal Rank (MRR) evaluates how soon the relevant item appears in the result list.
    """
    for rank, item in enumerate(actual_ids[:k], start=1):
        if item in expected_ids:
            return 1 / rank
    return 0


def precision(expected_ids, actual_ids, k):
    """
    Precision is the fraction of retrieved documents that are relevant.
    """
    relevant_items = [item for item in actual_ids[:k] if item in expected_ids]
    return len(relevant_items) / k


def recall(expected_ids, actual_ids, k, relevant_chunks):
    """
    Recall is the fraction of relevant documents that are retrieved.
    """
    relevant_items = [item for item in actual_ids[:k] if item in expected_ids]
    return min(1, len(relevant_items) / relevant_chunks)

# %%
def calculate_metrics(df, context_col, k):
    actual_ids_col = "actual_ids"
    df[actual_ids_col] = df[context_col].apply(
        lambda x: list([item["id"] // 10000 for item in x])
    )
    df["hit_rate"] = df.apply(
        lambda x: hit_rate([x["id"]], x[actual_ids_col], k), axis=1
    )
    df["mrr"] = df.apply(lambda x: mrr([x["id"]], x[actual_ids_col], k), axis=1)
    df["precision"] = df.apply(
        lambda x: precision([x["id"]], x[actual_ids_col], k), axis=1
    )
    df["recall"] = df.apply(
        lambda x: recall([x["id"]], x[actual_ids_col], k, x["relevant_chunks"]),
        axis=1,
    )

# %%
def describe_metric(df, metric_col, k, question_type):
    mean = df[metric_col].mean()
    std = df[metric_col].std()
    median = df[metric_col].median()
    q1 = df[metric_col].quantile(0.25)
    q3 = df[metric_col].quantile(0.75)
    confidence_99 = df[metric_col].quantile(1 - 0.99)
    confidence_95 = df[metric_col].quantile(1 - 0.95)
    confidence_90 = df[metric_col].quantile(1 - 0.90)
    error_point = len(df[df[metric_col] == 0]) / len(df)

    index = pd.MultiIndex.from_tuples(
        ((question_type, metric_col, k),), names=["question_type", "metric", "k"]
    )
    describe_metric = pd.DataFrame(
        {
            "mean": mean,
            "std": std,
            "median": median,
            "confidence_25": q3,
            "confidence_75": q1,
            "confidence_90": confidence_90,
            "confidence_95": confidence_95,
            "confidence_99": confidence_99,
            "zero_point": error_point,
        },
        index=index,
    )
    return describe_metric

# %%
df = pd.read_pickle("data/benchmark.pkl")
print(df.shape)
df.head()
# Out:
# (200, 12)
#      id                                      document_name  relevant_chunks  \
# 0  4461  Quyết định 08/2022/QĐ-UBND về tỷ lệ phần trăm ...                1
# 1  3101  Quyết định 330/QĐ-UBND năm 2023 về Kế hoạch tổ...                5
# 2   445  Nghị quyết 20/NQ-HĐND thông qua Danh mục điều ...                2
# 3   189  Nghị quyết 29/NQ-HĐND điều chỉnh danh mục các ...               15
# 4  3077  Quyết định 11/2023/QĐ-UBND quy định đơn giá câ...               18
#
#                                        easy_question  \
# 0  Tỷ lệ phần trăm điều tiết nguồn thu tiền sử dụ...
# 1  Dự thảo Luật Đất đai (sửa đổi) sẽ được lấy ý k...
# 2  Tỉnh Bà Rịa - Vũng Tàu có những huyện, thị xã,...
# 3  Nghị quyết 29/NQ-HĐND được ban hành vào ngày b...
# 4  Khi nào thì được áp dụng quyết định về đơn giá...
#
#                                          easy_answer  \
# 0  \n            Căn cứ tại Điều 1 Quyết định 08/...
# 1  \n            Căn cứ tại văn bản Quyết định 33...
# 2  \n            Căn cứ tại Nghị quyết 20/NQ-HĐND...
# 3  \n            Căn cứ tại phần đầu của Nghị quy...
# 4  \n            Căn cứ vào Điều 5 Quyết định 11/...
#
#                                      medium_question  \
# 0  Những cơ quan nào có trách nhiệm tổ chức thực ...
# 1  Mục đích của việc tổ chức lấy ý kiến Nhân dân ...
# 2  Dự án Đường Long Sơn - Cái Mép có diện tích đấ...
# 3  Nghị quyết 29/NQ-HĐND quy định về những dự án ...
# 4  Nếu cây trồng không được nêu trong Phụ lục đơn...
#
#                                        medium_answer  \
# 0  \n            Căn cứ tại khoản 2 Điều 2 Quyết ...
# 1  \n            Căn cứ tại văn bản Quyết định 33...
# 2  \n            Căn cứ tại Điều 2 Nghị quyết 20/...
# 3  \n            Căn cứ tại Điều 1 Nghị quyết 29/...
# 4  \n            Căn cứ vào khoản 3 Điều 3 Quyết ...
#
#                                        hard_question  \
# 0  Cơ quan nào có thẩm quyền ban hành Nghị quyết ...
# 1  Cơ quan nào sẽ chịu trách nhiệm thi hành Quyết...
# 2  Tỉnh Bà Rịa - Vũng Tàu có những dự án nào cần ...
# 3  Nghị quyết 29/NQ-HĐND quy định về việc thu hồi...
# 4  Trong trường hợp dự án, hạng mục dự án đã được...
#
#                                          hard_answer  \
# 0  \n            Căn cứ tại Điều 1 Quyết định 08/...
# 1  \n            Căn cứ tại văn bản Quyết định 33...
# 2  \n            Căn cứ tại Điều 1 Nghị quyết 20/...
# 3  \n            Căn cứ tại Điều 1 Nghị quyết 29/...
# 4  \n            Căn cứ vào khoản 2 Điều 5 Quyết ...
#
#                                      easy_embeddings  \
# 0  {'dense': [[-0.03312935, 0.0031744768, -0.0036...
# 1  {'dense': [[-0.0021552492, 0.037226226, 0.0037...
# 2  {'dense': [[-0.064513795, 0.066465534, -0.0119...
# 3  {'dense': [[-0.013742263, -0.009551991, -0.024...
# 4  {'dense': [[-0.062342368, 0.030936865, -0.0087...
#
#                                    medium_embeddings  \
# 0  {'dense': [[-0.058976743, -0.014345074, -0.024...
# 1  {'dense': [[-0.024163222, 0.00011042302, -0.01...
# 2  {'dense': [[-0.043495033, 0.008877934, -0.0416...
# 3  {'dense': [[-0.039806806, -0.010978846, -0.007...
# 4  {'dense': [[-0.055531275, 0.005023834, -0.0154...
#
#                                      hard_embeddings
# 0  {'dense': [[-0.056709077, 0.011795056, 0.00993...
# 1  {'dense': [[-0.005862655, 0.03228869, 0.001264...
# 2  {'dense': [[-0.0394588, 0.030524949, 0.0020539...
# 3  {'dense': [[-0.038123883, 0.032869037, -0.0161...
# 4  {'dense': [[-0.027396763, 0.024663005, 0.01161...

# %%
rerank = RRFRanker()
# rerank = WeightedRanker(0.9, 0.1)

# %%
df["easy_context"] = get_retrieval(df, "easy_embeddings", rerank, 10)
df["medium_context"] = get_retrieval(df, "medium_embeddings", rerank, 10)
df["hard_context"] = get_retrieval(df, "hard_embeddings", rerank, 10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 df["easy_context"] = get_retrieval(df, "easy_embeddings", rerank, 10)
#       2 df["medium_context"] = get_retrieval(df, "medium_embeddings", rerank, 10)
# ----> 3 df["hard_context"] = get_retrieval(df, "hard_embeddings", rerank, 10)
#
# Cell In[5], line 5, in get_retrieval(df, embed_col, rerank, limit)
#       2 full_context = []
#       4 for i, row in df.iterrows():
# ----> 5     res = query(row[embed_col], rerank=rerank, limit=limit)
#       7     context = []
#       8     for item in res[0]:
#
# Cell In[4], line 28, in query(query_embeds, rerank, limit)
#      21 content_dense_request = AnnSearchRequest(**content_dense_search_params)
#      23 reqs = [
#      24     content_sparse_request,
#      25     content_dense_request,
#      26 ]
# ---> 28 res = collection.hybrid_search(
#      29     reqs,  # List of AnnSearchRequests created in step 1
#      30     rerank,  # Reranking strategy specified in step 2
#      31     limit=limit,  # Number of final search results to return
#      32     output_fields=["id", "url", "title_text", "content_text"],
#      33 )
#      34 return res
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\pymilvus\orm\collection.py:945, in Collection.hybrid_search(self, reqs, rerank, limit, partition_names, output_fields, timeout, round_decimal, **kwargs)
#     942     return SearchFuture(None) if kwargs.get("_async", False) else resp
#     944 conn = self._get_connection()
# --> 945 resp = conn.hybrid_search(
#     946     self._name,
#     947     reqs,
#     948     rerank,
#     949     limit,
#     950     partition_names,
#     951     output_fields,
#     952     round_decimal,
#     953     timeout=timeout,
#     954     schema=self._schema_dict,
#     955     **kwargs,
#     956 )
#     958 return SearchFuture(resp) if kwargs.get("_async", False) else resp
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\pymilvus\decorators.py:144, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     142 try:
#     143     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 144     return func(*args, **kwargs)
#     145 except MilvusException as e:
#     146     record_dict["RPC error"] = str(datetime.datetime.now())
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\pymilvus\decorators.py:183, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     181 if req_id:
#     182     self.set_onetime_request_id(req_id)
# --> 183 return func(self, *args, **kwargs)
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\pymilvus\decorators.py:87, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      85 while True:
#      86     try:
# ---> 87         return func(*args, **kwargs)
#      88     except grpc.RpcError as e:
#      89         # Do not retry on these codes
#      90         if e.code() in IGNORE_RETRY_CODES:
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\pymilvus\client\grpc_handler.py:849, in GrpcHandler.hybrid_search(self, collection_name, reqs, rerank, limit, partition_names, output_fields, round_decimal, timeout, **kwargs)
#     837     requests.append(search_request)
#     839 hybrid_search_request = Prepare.hybrid_search_request_with_ranker(
#     840     collection_name,
#     841     requests,
#    (...)
#     847     **kwargs,
#     848 )
# --> 849 return self._execute_hybrid_search(
#     850     hybrid_search_request, timeout, round_decimal=round_decimal, **kwargs
#     851 )
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\pymilvus\client\grpc_handler.py:752, in GrpcHandler._execute_hybrid_search(self, request, timeout, **kwargs)
#     749     func = kwargs.get("_callback")
#     750     return SearchFuture(future, func)
# --> 752 response = self._stub.HybridSearch(request, timeout=timeout)
#     753 check_status(response.status)
#     754 round_decimal = kwargs.get("round_decimal", -1)
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\grpc\_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)
#     275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
#     282         wait_for_ready=wait_for_ready,
#     283         compression=compression,
#     284     )
#     285     return response
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\grpc\_interceptor.py:329, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     326     except Exception as exception:  # pylint:disable=broad-except
#     327         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
#     332 return call.result(), call
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\pymilvus\client\interceptor.py:35, in _GenericClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      31 def intercept_unary_unary(self, continuation: Callable, client_call_details: Any, request: Any):
#      32     new_details, new_request_iterator, postprocess = self._fn(
#      33         client_call_details, iter((request,))
#      34     )
# ---> 35     response = continuation(new_details, next(new_request_iterator))
#      36     return postprocess(response) if postprocess else response
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\grpc\_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     306 (
#     307     new_method,
#     308     new_timeout,
#    (...)
#     312     new_compression,
#     313 ) = _unwrap_client_call_details(new_details, client_call_details)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#     324 except grpc.RpcError as rpc_error:
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\grpc\_interceptor.py:343, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     334 def with_call(
#     335     self,
#     336     request: Any,
#    (...)
#     341     compression: Optional[grpc.Compression] = None,
#     342 ) -> Tuple[Any, grpc.Call]:
# --> 343     return self._with_call(
#     344         request,
#     345         timeout=timeout,
#     346         metadata=metadata,
#     347         credentials=credentials,
#     348         wait_for_ready=wait_for_ready,
#     349         compression=compression,
#     350     )
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\grpc\_interceptor.py:329, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     326     except Exception as exception:  # pylint:disable=broad-except
#     327         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
#     332 return call.result(), call
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\pymilvus\client\interceptor.py:35, in _GenericClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      31 def intercept_unary_unary(self, continuation: Callable, client_call_details: Any, request: Any):
#      32     new_details, new_request_iterator, postprocess = self._fn(
#      33         client_call_details, iter((request,))
#      34     )
# ---> 35     response = continuation(new_details, next(new_request_iterator))
#      36     return postprocess(response) if postprocess else response
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\grpc\_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     306 (
#     307     new_method,
#     308     new_timeout,
#    (...)
#     312     new_compression,
#     313 ) = _unwrap_client_call_details(new_details, client_call_details)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#     324 except grpc.RpcError as rpc_error:
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\grpc\_channel.py:1195, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1183 def with_call(
#    1184     self,
#    1185     request: Any,
#    (...)
#    1190     compression: Optional[grpc.Compression] = None,
#    1191 ) -> Tuple[Any, grpc.Call]:
#    1192     (
#    1193         state,
#    1194         call,
# -> 1195     ) = self._blocking(
#    1196         request, timeout, metadata, credentials, wait_for_ready, compression
#    1197     )
#    1198     return _end_unary_response_blocking(state, call, True, None)
#
# File c:\Person\CaoHoc\LLM\Project\rag\.venv\Lib\site-packages\grpc\_channel.py:1162, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1145 state.target = _common.decode(self._target)
#    1146 call = self._channel.segregated_call(
#    1147     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1148     self._method,
#    (...)
#    1160     self._registered_call_handle,
#    1161 )
# -> 1162 event = call.next_event()
#    1163 _handle_event(event, state, self._response_deserializer)
#    1164 return state, call
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/channel.pyx.pxi:213, in grpc._cython.cygrpc._next_call_event()
#
# File C:\Python312\Lib\threading.py:299, in Condition.__enter__(self)
#     296     self._lock._at_fork_reinit()
#     297     self._waiters.clear()
# --> 299 def __enter__(self):
#     300     return self._lock.__enter__()
#     302 def __exit__(self, *args):
#
# KeyboardInterrupt:

# %%
list_df = []
for context in ["easy_context", "medium_context", "hard_context"]:
    for k in [1, 2, 3, 5, 10]:
        calculate_metrics(df=df, context_col=context, k=k)
        for metric in ["hit_rate", "mrr", "precision", "recall"]:
            metrics = describe_metric(
                df=df,
                metric_col=metric,
                k=k,
                question_type=context.replace("_context", "_question"),
            )
            list_df.append(metrics)
full_metrics = pd.concat(list_df)
full_metrics.sort_index(level=[0, 1, 2], ascending=True, inplace=True)

# %%
full_metrics[full_metrics.index.get_level_values("question_type") == "easy_question"]
# Out:
#                                 mean       std    median  confidence_25  \
# question_type metric    k
# easy_question hit_rate  1   0.695000  0.461563  1.000000       1.000000
#                         2   0.695000  0.461563  1.000000       1.000000
#                         3   0.695000  0.461563  1.000000       1.000000
#                         5   0.695000  0.461563  1.000000       1.000000
#                         10  0.695000  0.461563  1.000000       1.000000
#               mrr       1   0.395000  0.490077  0.000000       1.000000
#                         2   0.460000  0.465816  0.500000       1.000000
#                         3   0.470000  0.459335  0.500000       1.000000
#                         5   0.486250  0.446321  0.500000       1.000000
#                         10  0.495962  0.437033  0.500000       1.000000
#               precision 1   0.395000  0.490077  0.000000       1.000000
#                         2   0.362500  0.388068  0.500000       0.500000
#                         3   0.321667  0.354248  0.333333       0.666667
#                         5   0.279000  0.303346  0.200000       0.400000
#                         10  0.208500  0.226793  0.100000       0.300000
#               recall    1   0.114393  0.223146  0.000000       0.125000
#                         2   0.190266  0.289137  0.035897       0.250000
#                         3   0.231427  0.325743  0.062500       0.375000
#                         5   0.315007  0.375683  0.142857       0.500000
#                         10  0.414721  0.408951  0.300905       1.000000
#
#                             confidence_75  confidence_90  confidence_95  \
# question_type metric    k
# easy_question hit_rate  1             0.0            0.0            0.0
#                         2             0.0            0.0            0.0
#                         3             0.0            0.0            0.0
#                         5             0.0            0.0            0.0
#                         10            0.0            0.0            0.0
#               mrr       1             0.0            0.0            0.0
#                         2             0.0            0.0            0.0
#                         3             0.0            0.0            0.0
#                         5             0.0            0.0            0.0
#                         10            0.0            0.0            0.0
#               precision 1             0.0            0.0            0.0
#                         2             0.0            0.0            0.0
#                         3             0.0            0.0            0.0
#                         5             0.0            0.0            0.0
#                         10            0.0            0.0            0.0
#               recall    1             0.0            0.0            0.0
#                         2             0.0            0.0            0.0
#                         3             0.0            0.0            0.0
#                         5             0.0            0.0            0.0
#                         10            0.0            0.0            0.0
#
#                             confidence_99  zero_point
# question_type metric    k
# easy_question hit_rate  1             0.0       0.305
#                         2             0.0       0.305
#                         3             0.0       0.305
#                         5             0.0       0.305
#                         10            0.0       0.305
#               mrr       1             0.0       0.605
#                         2             0.0       0.475
#                         3             0.0       0.445
#                         5             0.0       0.375
#                         10            0.0       0.305
#               precision 1             0.0       0.605
#                         2             0.0       0.475
#                         3             0.0       0.445
#                         5             0.0       0.375
#                         10            0.0       0.305
#               recall    1             0.0       0.605
#                         2             0.0       0.475
#                         3             0.0       0.445
#                         5             0.0       0.375
#                         10            0.0       0.305

# %%
full_metrics[full_metrics.index.get_level_values("question_type") == "medium_question"]
# Out:
#                                   mean       std    median  confidence_25  \
# question_type   metric    k
# medium_question hit_rate  1   0.675000  0.469550  1.000000       1.000000
#                           2   0.675000  0.469550  1.000000       1.000000
#                           3   0.675000  0.469550  1.000000       1.000000
#                           5   0.675000  0.469550  1.000000       1.000000
#                           10  0.675000  0.469550  1.000000       1.000000
#                 mrr       1   0.395000  0.490077  0.000000       1.000000
#                           2   0.455000  0.468050  0.500000       1.000000
#                           3   0.466667  0.460621  0.500000       1.000000
#                           5   0.482417  0.448056  0.500000       1.000000
#                           10  0.489234  0.441552  0.500000       1.000000
#                 precision 1   0.395000  0.490077  0.000000       1.000000
#                           2   0.380000  0.411029  0.500000       0.500000
#                           3   0.320000  0.348627  0.333333       0.666667
#                           5   0.271000  0.300015  0.200000       0.400000
#                           10  0.204000  0.244505  0.100000       0.300000
#                 recall    1   0.111736  0.233369  0.000000       0.100000
#                           2   0.202541  0.310847  0.029167       0.297619
#                           3   0.229726  0.327665  0.058846       0.333333
#                           5   0.295279  0.358261  0.142857       0.500000
#                           10  0.367772  0.385655  0.267857       0.666667
#
#                               confidence_75  confidence_90  confidence_95  \
# question_type   metric    k
# medium_question hit_rate  1             0.0            0.0            0.0
#                           2             0.0            0.0            0.0
#                           3             0.0            0.0            0.0
#                           5             0.0            0.0            0.0
#                           10            0.0            0.0            0.0
#                 mrr       1             0.0            0.0            0.0
#                           2             0.0            0.0            0.0
#                           3             0.0            0.0            0.0
#                           5             0.0            0.0            0.0
#                           10            0.0            0.0            0.0
#                 precision 1             0.0            0.0            0.0
#                           2             0.0            0.0            0.0
#                           3             0.0            0.0            0.0
#                           5             0.0            0.0            0.0
#                           10            0.0            0.0            0.0
#                 recall    1             0.0            0.0            0.0
#                           2             0.0            0.0            0.0
#                           3             0.0            0.0            0.0
#                           5             0.0            0.0            0.0
#                           10            0.0            0.0            0.0
#
#                               confidence_99  zero_point
# question_type   metric    k
# medium_question hit_rate  1             0.0       0.325
#                           2             0.0       0.325
#                           3             0.0       0.325
#                           5             0.0       0.325
#                           10            0.0       0.325
#                 mrr       1             0.0       0.605
#                           2             0.0       0.485
#                           3             0.0       0.450
#                           5             0.0       0.380
#                           10            0.0       0.325
#                 precision 1             0.0       0.605
#                           2             0.0       0.485
#                           3             0.0       0.450
#                           5             0.0       0.380
#                           10            0.0       0.325
#                 recall    1             0.0       0.605
#                           2             0.0       0.485
#                           3             0.0       0.450
#                           5             0.0       0.380
#                           10            0.0       0.325

# %%
full_metrics[full_metrics.index.get_level_values("question_type") == "hard_question"]
# Out:
#                                 mean       std    median  confidence_25  \
# question_type metric    k
# hard_question hit_rate  1   0.685000  0.465682  1.000000       1.000000
#                         2   0.685000  0.465682  1.000000       1.000000
#                         3   0.685000  0.465682  1.000000       1.000000
#                         5   0.685000  0.465682  1.000000       1.000000
#                         10  0.685000  0.465682  1.000000       1.000000
#               mrr       1   0.455000  0.499220  0.000000       1.000000
#                         2   0.500000  0.478167  0.500000       1.000000
#                         3   0.513333  0.468541  0.500000       1.000000
#                         5   0.525083  0.458334  0.500000       1.000000
#                         10  0.531938  0.451381  0.500000       1.000000
#               precision 1   0.455000  0.499220  0.000000       1.000000
#                         2   0.395000  0.405954  0.500000       0.500000
#                         3   0.345000  0.357386  0.333333       0.666667
#                         5   0.288000  0.309085  0.200000       0.400000
#                         10  0.214500  0.237321  0.100000       0.300000
#               recall    1   0.119754  0.226474  0.000000       0.129464
#                         2   0.199668  0.298642  0.043561       0.333333
#                         3   0.241298  0.317089  0.093074       0.500000
#                         5   0.306488  0.363041  0.142857       0.500000
#                         10  0.394707  0.394477  0.276190       0.770833
#
#                             confidence_75  confidence_90  confidence_95  \
# question_type metric    k
# hard_question hit_rate  1             0.0            0.0            0.0
#                         2             0.0            0.0            0.0
#                         3             0.0            0.0            0.0
#                         5             0.0            0.0            0.0
#                         10            0.0            0.0            0.0
#               mrr       1             0.0            0.0            0.0
#                         2             0.0            0.0            0.0
#                         3             0.0            0.0            0.0
#                         5             0.0            0.0            0.0
#                         10            0.0            0.0            0.0
#               precision 1             0.0            0.0            0.0
#                         2             0.0            0.0            0.0
#                         3             0.0            0.0            0.0
#                         5             0.0            0.0            0.0
#                         10            0.0            0.0            0.0
#               recall    1             0.0            0.0            0.0
#                         2             0.0            0.0            0.0
#                         3             0.0            0.0            0.0
#                         5             0.0            0.0            0.0
#                         10            0.0            0.0            0.0
#
#                             confidence_99  zero_point
# question_type metric    k
# hard_question hit_rate  1             0.0       0.315
#                         2             0.0       0.315
#                         3             0.0       0.315
#                         5             0.0       0.315
#                         10            0.0       0.315
#               mrr       1             0.0       0.545
#                         2             0.0       0.455
#                         3             0.0       0.415
#                         5             0.0       0.365
#                         10            0.0       0.315
#               precision 1             0.0       0.545
#                         2             0.0       0.455
#                         3             0.0       0.415
#                         5             0.0       0.365
#                         10            0.0       0.315
#               recall    1             0.0       0.545
#                         2             0.0       0.455
#                         3             0.0       0.415
#                         5             0.0       0.365
#                         10            0.0       0.315
